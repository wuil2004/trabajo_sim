# %% [markdown]
# # regrsion lineal costo de un incidente de

# %% [markdown]
# en este ejercicio se explica los fundamentos basicos de la regresion lineal aplicada a un caso de uso sencillo relacionado con la cibersegridad
#
# ## enunciado del ejercicio
#
# el erjercico consiste en predecir el costo de un incidente de seguridad en base a 1 numero de equipos que se han visto afectados. el conjunto de datos es generando de manera aleatroria

# %% [markdown]
# # 1.- generacion del DataSet

# %%
import numpy as np

X = 2 * np.random.rand(100,1)
y = 4 + 3 * X + np.random.randn(100, 1)

print("la longitud del DataSet es: ", len(X))
# Out:
# la longitud del DataSet es:  100

# %% [markdown]
# # 2.- visualizacion del DataSet

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(X, y, "b.")
plt.show()

# %%
plt.plot(X,y, "b.")
plt.xlabel("Equipos afectados (u/1,000)")
plt.ylabel("Costo del incidente (u/10,000)")
plt.show()

# %% [markdown]
# # 3.- Modificacion del DataSt

# %%
import pandas as pd

# %%
data = {'No_Equipos_Afectados': X.flatten, 'Costo': y.flatten()}
df = pd.DataFrame(data)
df.head(10)
# Out:
#                                 No_Equipos_Afectados      Costo
# 0  <built-in method flatten of numpy.ndarray obje...  11.346506
# 1  <built-in method flatten of numpy.ndarray obje...   4.669314
# 2  <built-in method flatten of numpy.ndarray obje...   9.494355
# 3  <built-in method flatten of numpy.ndarray obje...   7.601963
# 4  <built-in method flatten of numpy.ndarray obje...   5.256697
# 5  <built-in method flatten of numpy.ndarray obje...   6.716272
# 6  <built-in method flatten of numpy.ndarray obje...   7.959053
# 7  <built-in method flatten of numpy.ndarray obje...   8.174476
# 8  <built-in method flatten of numpy.ndarray obje...   4.550842
# 9  <built-in method flatten of numpy.ndarray obje...   7.265587

# %%
# Escaldo del numero de equipos afectados 
df['No_Equipos_Afectados'] = df['No_Equipos_Afectados'] * 1000
df['No_Equipos_Afectados'] = df['No_Equipos_Afectados'].astype('int')
# Escalado del costo 
df['Costo'] = df['Costo'] * 10000
df['Costo'] = df['Costo'].astype('int')
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/envs/Simulacion/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# File ~/anaconda3/envs/Simulacion/lib/python3.9/site-packages/pandas/core/computation/expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File ~/anaconda3/envs/Simulacion/lib/python3.9/site-packages/pandas/core/computation/expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# ...

# %% [markdown]
# # 4.- Construccion del modelo.
